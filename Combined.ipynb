# %%
#Hoshang Charania


import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import argparse
from influxdb import InfluxDBClient
from mpl_toolkits.mplot3d import Axes3D
worldbank = pd.read_csv('stocks.csv')
#worldbank.to_csv("stocks_norm.csv")

# %%
def read_data():
    with open('normalized_wb.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('normalized_wb.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx 35.196.46.176
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    influx_metric =[]
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            metric[j]=metric[j].replace("\n",""); # same as line 31
            narr[i]
            print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
            if(narr[i]!="year"):
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "yes"#name of column
                    },
                    'time': str(date)+"-12-31"+"T00:00:00Z",
                    'fields': {
                        narr[i] : float(metric[j]) #value of field
                    }
                }]
                client.write_points(influx_metric)
                date=date+1;
            print(influx_metric)
            
            

main()
# Out:
# Create DataFrame
# [[['' 'year' 'Population' 'Population growth' 'Surface area'
#    'GNI per capita_Atlas method' 'GNI per capita_PPP'
#    'Life expectancy at birth_total' 'Fertility rate_total '
#    'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#    'Births attended by skilled health staff' 'Mortality rate_under-5 '
#    'Prevalence of underweight_weight for age' 'Immunization_measles '
#    'School enrollment_secondary ' 'School enrollment_primary and secondary'
#    'Forest area' 'Water productivity_total' 'Improved water source '
#    'Improved sanitation facilities' 'Energy use '
#    'CO2 emissions (metric tons per capita)'
#    'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#    'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#    'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#    'Exports of goods and services (% of GDP)'
#    'Imports of goods and services (% of GDP)'
#    'Gross capital formation (% of GDP)'
#    'Revenue_excluding grants (% of GDP)'
#    'Market capitalization of listed domestic companies (% of GDP)'
#    'Military expenditure (% of GDP)'
#    'Mobile cellular subscriptions (per 100 people)'
#    'High-technology exports (% of manufactured exports)'
#    'Merchandise trade (% of GDP)'
#    'Net barter terms of trade index (2000 = 100)' 'Net migration'
#    'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']]]
# ['year' 'Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']
# ['year' 'Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']
# ['year' 'Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)']
# ['year' 'Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)']
# Create database: socialweather_norm
# year 97.17402082300445 1960-12-31T00:00:00Z
# []
# year 97.22359940505702 1960-12-31T00:00:00Z
# []
# year 97.27317798710958 1960-12-31T00:00:00Z
# []
# year 97.32275656916212 1960-12-31T00:00:00Z
# []
# year 97.37233515121467 1960-12-31T00:00:00Z
# []
# year 97.42191373326723 1960-12-31T00:00:00Z
# []
# year 97.47149231531978 1960-12-31T00:00:00Z
# []
# year 97.52107089737233 1960-12-31T00:00:00Z
# []
# year 97.57064947942489 1960-12-31T00:00:00Z
# []
# year 97.62022806147745 1960-12-31T00:00:00Z
# []
# year 97.66980664353 1960-12-31T00:00:00Z
# []
# year 97.71938522558254 1960-12-31T00:00:00Z
# []
# year 97.7689638076351 1960-12-31T00:00:00Z
# []
# year 97.81854238968765 1960-12-31T00:00:00Z
# []
# year 97.86812097174021 1960-12-31T00:00:00Z
# []
# year 97.91769955379276 1960-12-31T00:00:00Z
# []
# year 97.96727813584532 1960-12-31T00:00:00Z
# []
# year 98.01685671789787 1960-12-31T00:00:00Z
# []
# year 98.06643529995041 1960-12-31T00:00:00Z
# []
# year 98.11601388200297 1960-12-31T00:00:00Z
# []
# year 98.16559246405554 1960-12-31T00:00:00Z
# []
# year 98.21517104610808 1960-12-31T00:00:00Z
1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Population': 67.47645781558688}}]
# Population 68.15854148575706 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Population': 68.15854148575706}}]
# Population 68.88457065554799 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Population': 68.88457065554799}}]
# Population 69.64897476866973 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Population': 69.64897476866973}}]
# Population 70.32053627695888 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Population': 70.32053627695888}}]
# Population 71.01407053505841 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Population': 71.01407053505841}}]
# Population 71.69429735313192 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Population': 71.69429735313192}}]
# Population 72.3528608967445 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Population': 72.3528608967445}}]
# Population 72.98202428216008 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Population': 72.98202428216008}}]
# Population 73.63161304063885 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Population': 73.63161304063885}}]
# Population 74.31524408755624 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Population': 74.31524408755624}}]
# Population 74.98247294095319 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Population': 74.98247294095319}}]
# Population 75.66641346322001 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Population': 75.66641346322001}}]
# Population 76.38439627392546 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Population': 76.38439627392546}}]
# Population 77.25216515376083 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Population': 77.25216515376083}}]
# Population 78.29138337718707 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Population': 78.29138337718707}}]
# Population 79.38475978676567 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Population': 79.38475978676567}}]
# Population 80.43852335161569 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Population': 80.43852335161569}}]
# Population 81.43101079727619 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Population': 81.43101079727619}}]
# Population 82.40647709871737 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Population': 82.40647709871737}}]
# Population 83.37080228757866 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Population': 83.37080228757866}}]
# Population 84.3806203528079 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Population': 84.3806203528079}}]
# Population 85.37001304497397 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Population': 85.37001304497397}}]
# Population 86.3560015082962 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Population': 86.3560015082962}}]
# Population 87.32231074362275 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Population': 87.32231074362275}}]
# Population 88.1908669287471 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Population': 88.1908669287471}}]
# Population 89.01290711199823 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Population': 89.01290711199823}}]
# Population 89.78125394107185 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Population': 89.78125394107185}}]
# Population 90.61602191701948 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Population': 90.61602191701948}}]
# Population 91.45510274143693 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Population': 91.45510274143693}}]
# Population 92.34122753267377 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Population': 92.34122753267377}}]
# Population 93.22363304916101 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Population': 93.22363304916101}}]
# Population 94.10958639105424 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Population': 94.10958639105424}}]
# Population 94.93822613613222 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Population': 94.93822613613222}}]
# Population 95.73564012792684 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Population': 95.73564012792684}}]
# Population 96.45212662531773 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Population': 96.45212662531773}}]
# Population 97.17475806524713 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Population': 97.17475806524713}}]
# Population 97.85762439857605 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Population': 97.85762439857605}}]
# Population 98.58753686505179 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Population': 98.58753686505179}}]
# Population 99.30959299030658 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Population': 99.30959299030658}}]
# Population 100.0 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Population': 100.0}}]
# Population 0.0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Population': 0.0}}]
# Population growth 100.0 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Population growth': 100.0}}]
# Population growth 97.3993579409885 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Population growth': 97.3993579409885}}]
# Population growth 90.36450558332777 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Population growth': 90.36450558332777}}]
# Population growth 84.55763041114245 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Population growth': 84.55763041114245}}]
# Population growth 81.61292302593597 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Population growth': 81.61292302593597}}]
# Population growth 73.45340490831002 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Population growth': 73.45340490831002}}]
# Population growth 67.85535206768978 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Population growth': 67.85535206768978}}]
# Population growth 63.97684066082262 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Population growth': 63.97684066082262}}]
# Population growth 58.66423509504707 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Population growth': 58.66423509504707}}]
# Population growth 57.41756517454364 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Population growth': 57.41756517454364}}]
# Population growth 68.44933085165496 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Population growth': 68.44933085165496}}]
# Population growth 74.28549104823846 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Population growth': 74.28549104823846}}]
# Population growth 62.89819595397731 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'
1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.94110975831791 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Surface area': 97.94110975831791}}]
# Surface area 97.971013608286 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 97.971013608286 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Surface area': 97.971013608286}}]
# Surface area 100.0 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# Surface area 100.0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Surface area': 100.0}}]
# GNI per capita_Atlas method 0.0 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 0.0}}]
# GNI per capita_Atlas method 0.0 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 0.0}}]
# GNI per capita_Atlas method 5.773631402922021 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 5.773631402922021}}]
# GNI per capita_Atlas method 6.002464354867101 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 6.002464354867101}}]
# GNI per capita_Atlas method 6.354515050167224 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 6.354515050167224}}]
# GNI per capita_Atlas method 6.82978348882239 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 6.82978348882239}}]
# GNI per capita_Atlas method 7.375462066537581 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 7.375462066537581}}]
# GNI per capita_Atlas method 7.6923076923076925 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 7.6923076923076925}}]
# GNI per capita_Atlas method 8.343601478612921 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 8.343601478612921}}]
# GNI per capita_Atlas method 8.924485125858125 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 8.924485125858125}}]
# GNI per capita_Atlas method 9.434958634043303 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 9.434958634043303}}]
# GNI per capita_Atlas method 10.033444816053512 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 10.033444816053512}}]
# GNI per capita_Atlas method 11.071994367188875 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 11.071994367188875}}]
# GNI per capita_Atlas method 12.867452913219504 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 12.867452913219504}}]
# GNI per capita_Atlas method 14.08202781200493 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 14.08202781200493}}]
# GNI per capita_Atlas method 15.014962154550254 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 15.014962154550254}}]
# GNI per capita_Atlas method 15.807076218975533 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 15.807076218975533}}]
# GNI per capita_Atlas method 16.91603590917092 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 16.91603590917092}}]
# GNI per capita_Atlas method 18.993135011441648 1978-12-31T00:00:00Z
# ...
# GDP per capita (current US$) 83.92682830911697 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 83.92682830911697}}]
# GDP per capita (current US$) 86.38489893865902 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 86.38489893865902}}]
# GDP per capita (current US$) 89.26399300793491 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 89.26399300793491}}]
# GDP per capita (current US$) 91.58347140750085 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 91.58347140750085}}]
# GDP per capita (current US$) 94.72639576282484 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 94.72639576282484}}]
# GDP per capita (current US$) 97.97156928941048 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 97.97156928941048}}]
# GDP per capita (current US$) 100.0 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 100.0}}]
# GDP per capita (current US$) 0.0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 0.0}}]
# Inflation_consumer prices (annual %) 11.176904549332907 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 11.176904549332907}}]
# Inflation_consumer prices (annual %) 7.958786122047185 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 7.958786122047185}}]
# Inflation_consumer prices (annual %) 8.261461502180909 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 8.261461502180909}}]
# Inflation_consumer prices (annual %) 8.98730293375561 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 8.98730293375561}}]
# Inflation_consumer prices (annual %) 9.686721268525623 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 9.686721268525623}}]
# Inflation_consumer prices (annual %) 12.350395830772966 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 12.350395830772966}}]
# Inflation_consumer prices (annual %) 22.14019199960743 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 22.14019199960743}}]
# Inflation_consumer prices (annual %) 20.546006328927103 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 20.546006328927103}}]
# Inflation_consumer prices (annual %) 31.2207082489536 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 31.2207082489536}}]
# Inflation_consumer prices (annual %) 40.081072172369716 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 40.081072172369716}}]
# Inflation_consumer prices (annual %) 43.63856907459579 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 43.63856907459579}}]
# Inflation_consumer prices (annual %) 31.503532881535868 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 31.503532881535868}}]
# Inflation_consumer prices (annual %) 24.469051141926908 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 24.469051141926908}}]
# Inflation_consumer prices (annual %) 46.04258904789384 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 46.04258904789384}}]
# Inflation_consumer prices (annual %) 81.68597018540686 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 81.68597018540686}}]
# Inflation_consumer prices (annual %) 67.5970123842182 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 67.5970123842182}}]
# Inflation_consumer prices (annual %) 42.467020615016324 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 42.467020615016324}}]
# Inflation_consumer prices (annual %) 48.01452551489867 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 48.01452551489867}}]
# Inflation_consumer prices (annual %) 56.608588440405875 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 56.608588440405875}}]
# Inflation_consumer prices (annual %) 83.39429458811793 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 83.39429458811793}}]
# Inflation_consumer prices (annual %) 100.0 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 100.0}}]
# Inflation_consumer prices (annual %) 76.35836258846567 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 76.35836258846567}}]
# Inflation_consumer prices (annual %) 45.60254039612223 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 45.60254039612223}}]
# Inflation_consumer prices (annual %) 23.779311355957184 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 23.779311355957184}}]
# Inflation_consumer prices (annual %) 31.957589218001704 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 31.957589218001704}}]
# Inflation_consumer prices (annual %) 26.360343754082287 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 26.360343754082287}}]
# Inflation_consumer prices (annual %) 13.75886524386959 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 13.75886524386959}}]
# Inflation_consumer prices (annual %) 27.69097167832248 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 27.69097167832248}}]
# Inflation_consumer prices (annual %) 29.67635164384453 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 29.67635164384453}}]
# Inflation_consumer prices (annual %) 35.7307773203964 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 35.7307773203964}}]
# Inflation_consumer prices (annual %) 39.95712833493699 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 39.95712833493699}}]
# Inflation_consumer prices (annual %) 31.348344604896184 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 31.348344604896184}}]
# Inflation_consumer prices (annual %) 22.420139532883766 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 22.420139532883766}}]
# Inflation_consumer prices (annual %) 21.848960343068782 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 21.848960343068782}}]
# Inflation_consumer prices (annual %) 19.30098537760642 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 19.30098537760642}}]
# Inflation_consumer prices (annual %) 20.766472607313595 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 20.766472607313595}}]
# Inflation_consumer prices (annual %) 21.697563457052706 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 21.697563457052706}}]
# Inflation_consumer prices (annual %) 17.304210928386034 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 17.304210928386034}}]
# Inflation_consumer prices (annual %) 11.49038823484529 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 11.49038823484529}}]
# Inflation_consumer prices (annual %) 16.196366992331907 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 16.196366992331907}}]
# Inflation_consumer prices (annual %) 24.996407593484047 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 24.996407593484047}}]
# Inflation_consumer prices (annual %) 20.920080284748547 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 20.920080284748547}}]
# Inflation_consumer prices (annual %) 11.740233543512609 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 11.740233543512609}}]
# Inflation_consumer prices (annual %) 16.8038547878049 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 16.8038547878049}}]
# Inflation_consumer prices (annual %) 19.817627525205317 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 19.817627525205317}}]
# Inflation_consumer prices (annual %) 25.114026502521675 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 25.114026502521675}}]
# Inflation_consumer prices (annual %) 23.879307637575142 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 23.879307637575142}}]
# Inflation_consumer prices (annual %) 21.11625051587434 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 21.11625051587434}}]
# Inflation_consumer prices (annual %) 28.41805504786987 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 28.41805504786987}}]
# Inflation_consumer prices (annual %) -2.6318492817570127 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': -2.6318492817570127}}]
# Inflation_consumer prices (annual %) 12.140043554494815 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 12.140043554494815}}]
# Inflation_consumer prices (annual %) 23.367792072363745 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 23.367792072363745}}]
# Inflation_consumer prices (annual %) 15.317792128361916 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 15.317792128361916}}]
# Inflation_consumer prices (annual %) 10.843086096670799 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 10.843086096670799}}]
# Inflation_consumer prices (annual %) 12.008131669894047 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 12.008131669894047}}]
# Inflation_consumer prices (annual %) 0.878110031054275 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 0.878110031054275}}]
# Inflation_consumer prices (annual %) 9.338578891411588 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 9.338578891411588}}]
# Inflation_consumer prices (annual %) 0.0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 0.0}}]

# %%
def read_data():
    with open('worldbank.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('worldbank.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx 35.196.46.176
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    influx_metric =[]
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            metric[j]=metric[j].replace("\n",""); # same as line 31
            narr[i]
            print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
            if(narr[i]!="year"):
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "no"#name of column
                    },
                    'time': str(date)+"-12-31"+"T00:00:00Z",
                    'fields': {
                        narr[i] : float(metric[j]) #value of field
                    }
                }]
                client.write_points(influx_metric)
                date=date+1;
            print(influx_metric)          
main()
# Out:
# Create DataFrame
# [[['year' 'Population' 'Population growth' 'Surface area'
#    'GNI per capita_Atlas method' 'GNI per capita_PPP'
#    'Life expectancy at birth_total' 'Fertility rate_total '
#    'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#    'Births attended by skilled health staff' 'Mortality rate_under-5 '
#    'Prevalence of underweight_weight for age' 'Immunization_measles '
#    'School enrollment_secondary ' 'School enrollment_primary and secondary'
#    'Forest area' 'Water productivity_total' 'Improved water source '
#    'Improved sanitation facilities' 'Energy use '
#    'CO2 emissions (metric tons per capita)'
#    'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#    'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#    'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#    'Exports of goods and services (% of GDP)'
#    'Imports of goods and services (% of GDP)'
#    'Gross capital formation (% of GDP)'
#    'Revenue_excluding grants (% of GDP)'
#    'Market capitalization of listed domestic companies (% of GDP)'
#    'Military expenditure (% of GDP)'
#    'Mobile cellular subscriptions (per 100 people)'
#    'High-technology exports (% of manufactured exports)'
#    'Merchandise trade (% of GDP)'
#    'Net barter terms of trade index (2000 = 100)' 'Net migration'
#    'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']]]
# ['Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']
# ['Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)\n']
# ['Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)']
# ['Population' 'Population growth' 'Surface area'
#  'GNI per capita_Atlas method' 'GNI per capita_PPP'
#  'Life expectancy at birth_total' 'Fertility rate_total '
#  'Adolescent fertility rate ' 'Contraceptive prevalence_ any methods'
#  'Births attended by skilled health staff' 'Mortality rate_under-5 '
#  'Prevalence of underweight_weight for age' 'Immunization_measles '
#  'School enrollment_secondary ' 'School enrollment_primary and secondary'
#  'Forest area' 'Water productivity_total' 'Improved water source '
#  'Improved sanitation facilities' 'Energy use '
#  'CO2 emissions (metric tons per capita)'
#  'Electric power consumption (kWh per capita)' 'GDP growth (annual %)'
#  'Inflation_GDP deflator (annual %)' 'Agriculture_value added (% of GDP)'
#  'Industry_value added (% of GDP)' 'Services_value added (% of GDP)'
#  'Exports of goods and services (% of GDP)'
#  'Imports of goods and services (% of GDP)'
#  'Gross capital formation (% of GDP)' 'Revenue_excluding grants (% of GDP)'
#  'Market capitalization of listed domestic companies (% of GDP)'
#  'Military expenditure (% of GDP)'
#  'Mobile cellular subscriptions (per 100 people)'
#  'High-technology exports (% of manufactured exports)'
#  'Merchandise trade (% of GDP)'
#  'Net barter terms of trade index (2000 = 100)' 'Net migration'
#  'GDP per capita (current US$)' 'Inflation_consumer prices (annual %)']
# Create database: socialweather_norm
# Population 180671000 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Population': 180671000.0}}]
# Population 183691000 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Population': 183691000.0}}]
# Population 186538000 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Population': 186538000.0}}]
# Population 189242000 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Population': 189242000.0}}]
# Population 191889000 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Population': 191889000.0}}]
# Population 194303000 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Population': 194303000.0}}]
# Population 196560000 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Population': 196560000.0}}]
# Population 198712000 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Population': 198712000.0}}]
# Population 200706000 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Population': 200706000.0}}]
# Population 202677000 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Population': 202677000.0}}]
# Population 205052000 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Population': 205052000.0}}]
# Population 207661000 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Population': 207661000.0}}]
# Population 209896000 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Population': 209896000.0}}]
# Population 211909000 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Population': 211909000.0}}]
# Population 213854000 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Population': 213854000.0}}]
# Population 215973000 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Population': 215973000.0}}]
# Population 218035000 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Population': 218035000.0}}]
# Population 220239000 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Population': 220239000.0}}]
# Population 222585000 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Population': 222585000.0}}]
# Population 225055000 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Population': 225055000.0}}]
# Population 227225000 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Population': 227225000.0}}]
# Population 229466000 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Population': 229466000.0}}]
# Population 231664000 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Population': 231664000.0}}]
# Population 233792000 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Population': 233792000.0}}]
# Population 235825000 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Population': 235825000.0}}]
# Population 237924000 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Population': 237924000.0}}]
# Population 240133000 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Population': 240133000.0}}]
# Population 242289000 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Population': 242289000.0}}]
# Population 244499000 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Population': 244499000.0}}]
# Population 246819000 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Population': 246819000.0}}]
# Population 249623000 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Population': 249623000.0}}]
# Population 252981000 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Population': 252981000.0}}]
# Population 256514000 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Population': 256514000.0}}]
# Population 259919000 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Population': 259919000.0}}]
# Population 263126000 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Population': 263126000.0}}]
# Population 266278000 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Population': 266278000.0}}]
# Population 269394000 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Population': 269394000.0}}]
# Population 272657000 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Population': 272657000.0}}]
# Population 275854000 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Population': 275854000.0}}]
# Population 279040000 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Population': 279040000.0}}]
# Population 282162411 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Population': 282162411.0}}]
# Population 284968955 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Population': 284968955.0}}]
# Population 287625193 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Population': 287625193.0}}]
# Population 290107933 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Population': 290107933.0}}]
# Population 292805298 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Population': 292805298.0}}]
# Population 295516599 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Population': 295516599.0}}]
# Population 298379912 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Population': 298379912.0}}]
# Population 301231207 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Population': 301231207.0}}]
# Population 304093966 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Population': 304093966.0}}]
# Population 306771529 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Population': 306771529.0}}]
# Population 309348193 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Population': 309348193.0}}]
# Population 311663358 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Population': 311663358.0}}]
# Population 313998379 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Population': 313998379.0}}]
# Population 316204908 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Population': 316204908.0}}]
# Population 318563456 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Population': 318563456.0}}]
# Population 320896618 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Population': 320896618.0}}]
# Population 323127513 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Population': 323127513.0}}]
# Population 0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Population': 0.0}}]
# Population growth 1.701992777 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Population growth': 1.701992777}}]
# Population growth 1.657730037 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Population growth': 1.657730037}}]
# Population growth 1.537997358 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Population growth': 1.537997358}}]
# Population growth 1.439164762 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Population growth': 1.439164762}}]
# Population growth 1.389046055 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Population growth': 1.389046055}}]
# Population growth 1.250171646 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Population growth': 1.250171646}}]
# Population growth 1.154893191 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Population growth': 1.154893191}}]
# Population growth 1.088881207 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Population growth': 1.088881207}}]
# Population growth 0.998461044 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Population growth': 0.998461044}}]
# Population growth 0.977242812 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Population growth': 0.977242812}}]
# Population growth 1.165002667 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Population growth': 1.165002667}}]
# Population growth 1.264333692 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Population growth': 1.264333692}}]
# Population growth 1.070522752 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Population growth': 1.070522752}}]
# Population growth 0.954476729 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Population growth': 0.954476729}}]
# Population growth 0.913660196 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Population growth': 0.913660196}}]
# Population growth 0.985986067 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Population growth': 0.985986067}}]
# Population growth 0.950220049 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Population growth': 0.950220049}}]
# Population growth 1.005771996 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Population growth': 1.005771996}}]
# Population growth 1.05957308 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Population growth': 1.05957308}}]
# Population growth 1.103576565 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Population growth': 1.103576565}}]
# Population growth 0.959589923 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Population growth': 0.959589923}}]
# Population growth 0.981415437 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Population growth': 0.981415437}}]
# Population growth 0.953317566 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Population growth': 0.953317566}}]
# Population growth 0.914378513 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Population growth': 0.914378513}}]
# Population growth 0.865817336 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Population growth': 0.865817336}}]
# Population growth 0.886129041 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Population growth': 0.886129041}}]
# Population growth 0.924164157 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Population growth': 0.924164157}}]
# Population growth 0.893829201 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Population growth': 0.893829201}}]
# Population growth 0.90799904 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Population growth': 0.90799904}}]
# Population growth 0.944405555 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Population growth': 0.944405555}}]
# Population growth 1.12965052 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Population growth': 1.12965052}}]
# Population growth 1.336260741 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Population growth': 1.336260741}}]
# Population growth 1.386885692 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Population growth': 1.386885692}}]
# Population growth 1.31868 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Population growth': 1.31868}}]
# Population growth 1.226296089 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Population growth': 1.226296089}}]
# Population growth 1.190787091 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Population growth': 1.190787091}}]
# Population growth 1.16341162 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Population growth': 1.16341162}}]
# Population growth 1.203960297 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Population growth': 1.203960297}}]
# Population growth 1.165714526 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Population growth': 1.165714526}}]
# Population growth 1.148340047 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Population growth': 1.148340047}}]
# Population growth 1.112768997 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Population growth': 1.112768997}}]
# Population growth 0.989741382 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Population growth': 0.989741382}}]
# Population growth 0.927797486 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Population growth': 0.927797486}}]
# Population growth 0.859481713 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Population growth': 0.859481713}}]
# Population growth 0.925483969 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Population growth': 0.925483969}}]
# Population growth 0.921713167 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Population growth': 0.921713167}}]
# Population growth 0.964253917 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Population growth': 0.964253917}}]
# Population growth 0.951055243 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Population growth': 0.951055243}}]
# Population growth 0.945865287 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Population growth': 0.945865287}}]
# Population growth 0.876651299 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Population growth': 0.876651299}}]
# Population growth 0.836421536 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Population growth': 0.836421536}}]
# Population growth 0.745614384 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Population growth': 0.745614384}}]
# Population growth 0.746419895 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Population growth': 0.746419895}}]
# Population growth 0.7002623 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Population growth': 0.7002623}}]
# Population growth 0.74312426 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Population growth': 0.74312426}}]
# Population growth 0.729731987 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Population growth': 0.729731987}}]
# Population growth 0.692801346 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Population growth': 0.692801346}}]
# Population growth 0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Population growth': 0.0}}]
# Surface area 0 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Surface area': 0.0}}]
# Surface area 9629090 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9629090 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Surface area': 9629090.0}}]
# Surface area 9632030 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9632030 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Surface area': 9632030.0}}]
# Surface area 9831510 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# Surface area 9831510 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Surface area': 9831510.0}}]
# GNI per capita_Atlas method 0 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 0.0}}]
# GNI per capita_Atlas method 0 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 0.0}}]
# GNI per capita_Atlas method 3280 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 3280.0}}]
# GNI per capita_Atlas method 3410 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 3410.0}}]
# GNI per capita_Atlas method 3610 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 3610.0}}]
# GNI per capita_Atlas method 3880 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 3880.0}}]
# GNI per capita_Atlas method 4190 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 4190.0}}]
# GNI per capita_Atlas method 4370 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 4370.0}}]
# GNI per capita_Atlas method 4740 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 4740.0}}]
# GNI per capita_Atlas method 5070 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 5070.0}}]
# GNI per capita_Atlas method 5360 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 5360.0}}]
# GNI per capita_Atlas method 5700 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 5700.0}}]
# GNI per capita_Atlas method 6290 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 6290.0}}]
# GNI per capita_Atlas method 7310 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 7310.0}}]
# GNI per capita_Atlas method 8000 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 8000.0}}]
# GNI per capita_Atlas method 8530 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 8530.0}}]
# GNI per capita_Atlas method 8980 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 8980.0}}]
# GNI per capita_Atlas method 9610 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 9610.0}}]
# GNI per capita_Atlas method 10790 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 10790.0}}]
# GNI per capita_Atlas method 12230 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 12230.0}}]
# GNI per capita_Atlas method 13410 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 13410.0}}]
# GNI per capita_Atlas method 14400 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 14400.0}}]
# GNI per capita_Atlas method 14230 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 14230.0}}]
# GNI per capita_Atlas method 14590 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 14590.0}}]
# GNI per capita_Atlas method 16230 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 16230.0}}]
# GNI per capita_Atlas method 17510 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 17510.0}}]
# GNI per capita_Atlas method 19160 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 19160.0}}]
# GNI per capita_Atlas method 21460 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 21460.0}}]
# GNI per capita_Atlas method 23580 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 23580.0}}]
# GNI per capita_Atlas method 23860 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 23860.0}}]
# GNI per capita_Atlas method 24150 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 24150.0}}]
# GNI per capita_Atlas method 24370 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 24370.0}}]
# GNI per capita_Atlas method 25780 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 25780.0}}]
# GNI per capita_Atlas method 26480 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 26480.0}}]
# GNI per capita_Atlas method 27750 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 27750.0}}]
# GNI per capita_Atlas method 29150 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 29150.0}}]
# GNI per capita_Atlas method 30380 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 30380.0}}]
# GNI per capita_Atlas method 31390 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 31390.0}}]
# GNI per capita_Atlas method 32150 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 32150.0}}]
# GNI per capita_Atlas method 33780 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 33780.0}}]
# GNI per capita_Atlas method 36070 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 36070.0}}]
# GNI per capita_Atlas method 36840 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 36840.0}}]
# GNI per capita_Atlas method 37470 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 37470.0}}]
# GNI per capita_Atlas method 39950 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 39950.0}}]
# GNI per capita_Atlas method 43680 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'GNI per capita_Atlas method': 43680.0}}]
# GNI per capita_Atlas method 46340 2005-12-31T00:00:00Z
# ...
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 46437.06712}}]
# GDP per capita (current US$) 48061.53766 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 48061.53766}}]
# GDP per capita (current US$) 48401.42734 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 48401.42734}}]
# GDP per capita (current US$) 47001.55535 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 47001.55535}}]
# GDP per capita (current US$) 48373.87882 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 48373.87882}}]
# GDP per capita (current US$) 49790.66548 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 49790.66548}}]
# GDP per capita (current US$) 51450.1223 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 51450.1223}}]
# GDP per capita (current US$) 52787.02695 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 52787.02695}}]
# GDP per capita (current US$) 54598.55069 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 54598.55069}}]
# GDP per capita (current US$) 56469.00897 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 56469.00897}}]
# GDP per capita (current US$) 57638.15909 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 57638.15909}}]
# GDP per capita (current US$) 0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'GDP per capita (current US$)': 0.0}}]
# Inflation_consumer prices (annual %) 1.509929427 1960-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.509929427}}]
# Inflation_consumer prices (annual %) 1.075181891 1961-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.075181891}}]
# Inflation_consumer prices (annual %) 1.116071429 1962-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.116071429}}]
# Inflation_consumer prices (annual %) 1.214128036 1963-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.214128036}}]
# Inflation_consumer prices (annual %) 1.308615049 1964-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.308615049}}]
# Inflation_consumer prices (annual %) 1.66846071 1965-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.66846071}}]
# Inflation_consumer prices (annual %) 2.991000529 1966-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.991000529}}]
# Inflation_consumer prices (annual %) 2.775636083 1967-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.775636083}}]
# Inflation_consumer prices (annual %) 4.217721097 1968-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.217721097}}]
# Inflation_consumer prices (annual %) 5.414700472 1969-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 5.414700472}}]
# Inflation_consumer prices (annual %) 5.895295903 1970-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 5.895295903}}]
# Inflation_consumer prices (annual %) 4.255928924 1971-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.255928924}}]
# Inflation_consumer prices (annual %) 3.305614735 1972-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.305614735}}]
# Inflation_consumer prices (annual %) 6.220063864 1973-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 6.220063864}}]
# Inflation_consumer prices (annual %) 11.03526022 1974-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 11.03526022}}]
# Inflation_consumer prices (annual %) 9.131930735 1975-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 9.131930735}}]
# Inflation_consumer prices (annual %) 5.737027083 1976-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 5.737027083}}]
# Inflation_consumer prices (annual %) 6.486460064 1977-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 6.486460064}}]
# Inflation_consumer prices (annual %) 7.647463851 1978-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 7.647463851}}]
# Inflation_consumer prices (annual %) 11.26604409 1979-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 11.26604409}}]
# Inflation_consumer prices (annual %) 13.50937033 1980-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 13.50937033}}]
# Inflation_consumer prices (annual %) 10.31553398 1981-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 10.31553398}}]
# Inflation_consumer prices (annual %) 6.160616062 1982-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 6.160616062}}]
# Inflation_consumer prices (annual %) 3.212435233 1983-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.212435233}}]
# Inflation_consumer prices (annual %) 4.317269076 1984-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.317269076}}]
# Inflation_consumer prices (annual %) 3.561116458 1985-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.561116458}}]
# Inflation_consumer prices (annual %) 1.858736059 1986-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.858736059}}]
# Inflation_consumer prices (annual %) 3.740875912 1987-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.740875912}}]
# Inflation_consumer prices (annual %) 4.009088244 1988-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.009088244}}]
# Inflation_consumer prices (annual %) 4.82700303 1989-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.82700303}}]
# Inflation_consumer prices (annual %) 5.39795644 1990-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 5.39795644}}]
# Inflation_consumer prices (annual %) 4.234963965 1991-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 4.234963965}}]
# Inflation_consumer prices (annual %) 3.028819678 1992-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.028819678}}]
# Inflation_consumer prices (annual %) 2.951656966 1993-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.951656966}}]
# Inflation_consumer prices (annual %) 2.607441592 1994-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.607441592}}]
# Inflation_consumer prices (annual %) 2.805419689 1995-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.805419689}}]
# Inflation_consumer prices (annual %) 2.9312042 1996-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.9312042}}]
# Inflation_consumer prices (annual %) 2.337689937 1997-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.337689937}}]
# Inflation_consumer prices (annual %) 1.552279099 1998-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.552279099}}]
# Inflation_consumer prices (annual %) 2.188027197 1999-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.188027197}}]
# Inflation_consumer prices (annual %) 3.376857271 2000-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.376857271}}]
# Inflation_consumer prices (annual %) 2.826171119 2001-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.826171119}}]
# Inflation_consumer prices (annual %) 1.586031627 2002-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.586031627}}]
# Inflation_consumer prices (annual %) 2.270094973 2003-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.270094973}}]
# Inflation_consumer prices (annual %) 2.677236693 2004-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.677236693}}]
# Inflation_consumer prices (annual %) 3.392746845 2005-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.392746845}}]
# Inflation_consumer prices (annual %) 3.225944101 2006-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.225944101}}]
# Inflation_consumer prices (annual %) 2.852672482 2007-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.852672482}}]
# Inflation_consumer prices (annual %) 3.839100297 2008-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.839100297}}]
# Inflation_consumer prices (annual %) -0.355546266 2009-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': -0.355546266}}]
# Inflation_consumer prices (annual %) 1.640043442 2010-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.640043442}}]
# Inflation_consumer prices (annual %) 3.156841569 2011-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 3.156841569}}]
# Inflation_consumer prices (annual %) 2.069337265 2012-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 2.069337265}}]
# Inflation_consumer prices (annual %) 1.464832656 2013-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.464832656}}]
# Inflation_consumer prices (annual %) 1.622222977 2014-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.622222977}}]
# Inflation_consumer prices (annual %) 0.118627136 2015-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 0.118627136}}]
# Inflation_consumer prices (annual %) 1.261583206 2016-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 1.261583206}}]
# Inflation_consumer prices (annual %) 0 2017-12-31T00:00:00Z
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Inflation_consumer prices (annual %)': 0.0}}]

# %%
def read_data():
    with open('stocks_norm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('stocks_norm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "yes"
                    },
                    'time': str(metric[1]),
                    'fields': {
                    narr[i] : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['' 'dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']]]
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000']
# Create database: socialweather_norm
# 58
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'SP500': 2.289118149851508}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'SP500': 2.7163040749513705}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'SP500': 2.556865048936646}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'SP500': 2.8635494993621413}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'SP500': 3.335035428048358}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'SP500': 3.6138146333465953}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'SP500': 3.494406142569502}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'SP500': 3.7678570513685354}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'SP500': 4.045167559554814}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'SP500': 4.010157919095283}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'SP500': 3.410929497415264}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'SP500': 4.02832877638745}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'SP500': 4.476110616801552}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'SP500': 4.402949007177829}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'SP500': 3.383570744236644}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'SP500': 3.531260193355682}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'SP500': 4.181551456486432}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'SP500': 4.025323070669947}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'SP500': 3.9355617681063872}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'SP500': 4.222572508380966}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'SP500': 4.868560147416204}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'SP500': 5.248030494250734}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'SP500': 4.907156141288663}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'SP500': 6.575322814501848}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'SP500': 6.577030601841336}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'SP500': 7.658401545205984}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'SP500': 9.687594461987214}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'SP500': 11.756749602512496}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'SP500': 10.893633881134585}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'SP500': 13.231936306363384}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'SP500': 13.713703114833331}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'SP500': 15.418348125618007}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'SP500': 17.040062983197085}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'SP500': 18.501758167066004}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'SP500': 18.86746374794425}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'SP500': 22.200074117970527}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'SP500': 27.495171231297594}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'SP500': 35.768171284238996}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'SP500': 44.442535517707185}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'SP500': 54.35111766142433}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'SP500': 58.48860820455193}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'SP500': 48.8595908483092}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'SP500': 40.807783411578455}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'SP500': 39.49862779287272}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'SP500': 46.337632972591734}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'SP500': 49.473677019842775}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'SP500': 53.72029517396374}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'SP500': 60.522617081630514}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'SP500': 50.04042332632569}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'SP500': 38.80376328018131}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'SP500': 46.69667818284595}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'SP500': 52.007862652910994}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'SP500': 56.54401907256901}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'SP500': 67.32145510312473}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'SP500': 79.13206831832473}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'SP500': 84.48215618398335}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'SP500': 85.73819961643096}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'SP500': 100.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'DJIA': 3.5140794768853985}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'DJIA': 3.933223476487288}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'DJIA': 3.634142482825235}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'DJIA': 4.063747341895963}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'DJIA': 4.742615537628633}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'DJIA': 5.178263196698662}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'DJIA': 4.962648846083776}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'DJIA': 5.000736325849794}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'DJIA': 5.139917839397393}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'DJIA': 4.979355135543784}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'DJIA': 4.282235866723607}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'DJIA': 5.031389488089458}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'DJIA': 5.402373323587507}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'DJIA': 5.2542684353628335}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'DJIA': 4.316416151897547}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'DJIA': 4.565231395629017}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'DJIA': 5.544999682554594}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'DJIA': 5.08516022027282}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'DJIA': 4.668973493914792}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'DJIA': 4.801243231183379}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'DJIA': 5.0669398525380345}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'DJIA': 5.304540174620082}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'DJIA': 5.029435793496193}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'DJIA': 6.7707889782089925}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'DJIA': 6.701243249069207}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'DJIA': 7.550986546756872}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'DJIA': 10.19560503725717}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'DJIA': 12.950068094963507}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'DJIA': 11.721569742064535}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'DJIA': 14.273790815825704}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'DJIA': 15.235390714960072}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'DJIA': 16.65452475642516}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'DJIA': 18.673295652345523}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'DJIA': 20.042712581558604}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'DJIA': 21.576023924184813}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'DJIA': 25.58356667686199}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'DJIA': 32.65979211336931}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'DJIA': 42.321789531442086}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'DJIA': 49.081305654604066}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'DJIA': 59.60418272273101}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'DJIA': 60.97534616242988}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'DJIA': 58.030099182944284}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'DJIA': 52.39573194201213}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'DJIA': 51.211814009709336}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'DJIA': 58.65409490153767}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'DJIA': 59.96837473576839}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'DJIA': 64.87610620866491}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'DJIA': 74.93165778639509}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'DJIA': 63.93376041145341}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'DJIA': 50.52391233451754}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'DJIA': 60.661689852213094}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'DJIA': 67.99084782755045}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'DJIA': 73.72073655608409}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'DJIA': 85.34428043430773}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'DJIA': 95.39809568575569}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'DJIA': 100.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'DJIA': 95.66889376569426}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'DJIA': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'NASDAQ': 33.52662149263666}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'NASDAQ': 40.164267969813686}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'NASDAQ': 42.4588016765713}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'NASDAQ': 45.766565133541256}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'NASDAQ': 52.13706853406155}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'NASDAQ': 43.76140334108688}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'NASDAQ': 37.314022854648954}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'NASDAQ': 47.51527883617249}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'NASDAQ': 54.13834303040922}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'NASDAQ': 59.964154159065565}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'NASDAQ': 71.60557517965394}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'NASDAQ': 88.46539622075777}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'NASDAQ': 100.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Russell1000': 62.19596038583452}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Russell1000': 68.0397487905486}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Russell1000': 86.3078168813556}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Russell1000': 98.34321526581378}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Russell1000': 100.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]

# %% [markdown]
# Normalized data in dataframe

# %%
def read_data():
    with open('stocks.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('stocks.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "no"
                    },
                    'time': str(metric[1]),
                    'fields': {
                    narr[i] : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['' 'dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']]]
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000\n']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000']
# ['dates' 'SP500' 'DJIA' 'NASDAQ' 'Russell1000']
# Create database: socialweather_norm
# 58
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'SP500': 55.849999999999994}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'SP500': 66.2725}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'SP500': 62.38249999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'SP500': 69.865}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'SP500': 81.36833333333334}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'SP500': 88.16999999999997}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'SP500': 85.25666666666666}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'SP500': 91.92833333333333}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'SP500': 98.69416666666666}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'SP500': 97.83999999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'SP500': 83.22}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'SP500': 98.28333333333335}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'SP500': 109.20833333333333}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'SP500': 107.42333333333333}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'SP500': 82.5525}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'SP500': 86.15583333333332}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {
}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'DJIA': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'NASDAQ': 1658.0770000000007}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'NASDAQ': 1986.3453571428588}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'NASDAQ': 2099.8227490039835}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'NASDAQ': 2263.409960159361}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'NASDAQ': 2578.4666135458156}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'NASDAQ': 2164.243611111111}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'NASDAQ': 1845.3849603174601}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'NASDAQ': 2349.893531746033}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'NASDAQ': 2677.4407142857144}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'NASDAQ': 2965.559320000002}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'NASDAQ': 3541.2920238095235}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'NASDAQ': 4375.103492063489}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'NASDAQ': 4945.55349206349}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'NASDAQ': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1960-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1961-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1962-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1967-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1968-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1969-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Russell1000': 886.7049375}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Russell1000': 970.01768}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Russell1000': 1230.458809523808}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Russell1000': 1402.043058823529}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Russell1000': 1425.6632295719837}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2016-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2017-12-31T00:00:00Z', 'fields': {'Russell1000': 0.0}}]

# %% [markdown]
# print("test")

# %%
def read_data():
    with open('happiness.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('happiness.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "yes"
                    },
                    'time': str(metric[1]),
                    'fields': {
                    narr[i] : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['' 'dates' 'happiness\n']]]
# ['dates' 'happiness\n']
# ['dates' 'happiness\n']
# ['dates' 'happiness']
# ['dates' 'happiness']
# Create database: socialweather_norm
# 46
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1946-12-31T00:00:00Z', 'fields': {'happiness': 76.3257}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1947-12-31T00:00:00Z', 'fields': {'happiness': 77.3256}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1948-12-31T00:00:00Z', 'fields': {'happiness': 77.6589}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1952-12-31T00:00:00Z', 'fields': {'happiness': 79.32539999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1956-12-31T00:00:00Z', 'fields': {'happiness': 82.6584}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1957-12-31T00:00:00Z', 'fields': {'happiness': 81.241875}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'happiness': 77.25894}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'happiness': 74.99249999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'happiness': 70.99289999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'happiness': 80.908575}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'happiness': 66.66}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'happiness': 71.14103333333333}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'happiness': 74.32589999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'happiness': 72.04834999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'happiness': 73.8815}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'happiness': 73.49265}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'happiness': 77.3256}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'happiness': 75.6591}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'happiness': 79.19208}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'happiness': 78.9921}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'happiness': 73.49265}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'happiness': 74.32589999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'happiness': 73.9926}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'happiness': 71.82614999999998}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'happiness': 74.99249999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'happiness': 76.3257}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'happiness': 77.9922}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'happiness': 85.9914}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'happiness': 77.82554999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'happiness': 76.9923}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'happiness': 78.65879999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'happiness': 75.32579999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'happiness': 77.49225}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'happiness': 83.65829999999998}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'happiness': 77.9922}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'happiness': 79.82535}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'happiness': 77.6589}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'happiness': 74.7703}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'happiness': 70.32629999999999}}]

# %%
def read_data():
    with open('happiness.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('happiness.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "no"
                    },
                    'time': str(metric[1]),
                    'fields': {
                    narr[i] : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['' 'dates' 'happiness\n']]]
# ['dates' 'happiness\n']
# ['dates' 'happiness\n']
# ['dates' 'happiness']
# ['dates' 'happiness']
# Create database: socialweather_norm
# 46
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1946-12-31T00:00:00Z', 'fields': {'happiness': 76.3257}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1947-12-31T00:00:00Z', 'fields': {'happiness': 77.3256}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1948-12-31T00:00:00Z', 'fields': {'happiness': 77.6589}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1952-12-31T00:00:00Z', 'fields': {'happiness': 79.32539999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1956-12-31T00:00:00Z', 'fields': {'happiness': 82.6584}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1957-12-31T00:00:00Z', 'fields': {'happiness': 81.241875}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1963-12-31T00:00:00Z', 'fields': {'happiness': 77.25894}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1964-12-31T00:00:00Z', 'fields': {'happiness': 74.99249999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1965-12-31T00:00:00Z', 'fields': {'happiness': 70.99289999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1966-12-31T00:00:00Z', 'fields': {'happiness': 80.908575}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'happiness': 66.66}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'happiness': 71.14103333333333}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'happiness': 74.32589999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'happiness': 72.04834999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'happiness': 73.8815}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'happiness': 73.49265}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'happiness': 77.3256}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'happiness': 75.6591}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'happiness': 79.19208}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'happiness': 78.9921}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'happiness': 73.49265}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'happiness': 74.32589999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'happiness': 73.9926}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'happiness': 71.82614999999998}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'happiness': 74.99249999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'happiness': 76.3257}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'happiness': 77.9922}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'happiness': 74.6592}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'happiness': 72.9927}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'happiness': 85.9914}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'happiness': 77.82554999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'happiness': 76.9923}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'happiness': 78.65879999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'happiness': 75.32579999999999}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'happiness': 77.49225}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'happiness': 83.65829999999998}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'happiness': 77.9922}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'happiness': 79.82535}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'happiness': 77.6589}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'happiness': 74.7703}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'happiness': 70.32629999999999}}]

# %%
def read_data():
    with open('internet.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('internet.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "yes"
                    },
                    'time': str(metric[0])+"-12-31"+"T00:00:00Z",
                    'fields': {
                    "internet_usage" : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['\ufeffdates' 'percentage\n']]]
# ['percentage\n']
# ['percentage\n']
# ['percentage']
# ['percentage']
# Create database: socialweather_norm
# 26
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'internet_usage': 74.55}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'internet_usage': 73.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'internet_usage': 71.4}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'internet_usage': 74.7}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'internet_usage': 69.72946076}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'internet_usage': 71.69}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'internet_usage': 71.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'internet_usage': 74.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'internet_usage': 75.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'internet_usage': 68.93119327}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'internet_usage': 67.96805292}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'internet_usage': 64.75825648}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'internet_usage': 61.69711712}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'internet_usage': 58.78540388}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'internet_usage': 49.08083159}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'internet_usage': 43.07916264}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'internet_usage': 35.84872446}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'internet_usage': 30.09319659}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'internet_usage': 21.61640097}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'internet_usage': 16.41935296}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'internet_usage': 9.237088297}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'internet_usage': 4.862780635}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'internet_usage': 2.271673294}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'internet_usage': 1.724202539}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'internet_usage': 1.163193726}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'internet_usage': 0.784728502}}]

# %%
def read_data():
    with open('internet.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('internet.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    print(len(a))
    for i in range(len(narr)):
        j=j+1;
        date=1960
        for metric in a:
            if(narr[i]!="dates"):
                metric[j]=metric[j].replace("\n",""); # same as line 31
                if(metric[j]==''):
                    metric[j]=0;
                narr[i]
                #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                influx_metric = [{
                    'measurement': 'socialweather', #name of the table 
                    'tags': {
                        'normalized': "no"
                    },
                    'time': str(metric[0])+"-12-31"+"T00:00:00Z",
                    'fields': {
                    "internet_usage" : float(metric[j]) #value of field
                    }
                }]
                print(influx_metric)
                client.write_points(influx_metric)
                date=date+1;

main()
# Out:
# Create DataFrame
# [[['\ufeffdates' 'percentage\n']]]
# ['percentage\n']
# ['percentage\n']
# ['percentage']
# ['percentage']
# Create database: socialweather_norm
# 26
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'internet_usage': 74.55}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'internet_usage': 73.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'internet_usage': 71.4}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'internet_usage': 74.7}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'internet_usage': 69.72946076}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'internet_usage': 71.69}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'internet_usage': 71.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'internet_usage': 74.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'internet_usage': 75.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'internet_usage': 68.93119327}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'internet_usage': 67.96805292}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'internet_usage': 64.75825648}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'internet_usage': 61.69711712}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'internet_usage': 58.78540388}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'internet_usage': 49.08083159}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'internet_usage': 43.07916264}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'internet_usage': 35.84872446}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'internet_usage': 30.09319659}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'internet_usage': 21.61640097}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'internet_usage': 16.41935296}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'internet_usage': 9.237088297}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'internet_usage': 4.862780635}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'internet_usage': 2.271673294}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'internet_usage': 1.724202539}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'internet_usage': 1.163193726}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'internet_usage': 0.784728502}}]

# %%
def read_data():
    with open('terr_unnorm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('terr_unnorm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    influx_metric=[]
    for i in range(len(narr)):
        j=j+1;
        date=1970
        for metric in a:
            metric[j]=metric[j].replace("\n",""); # same as line 31
            narr[i]
            if(narr[i]!='iyear'):
                try:
                    float(metric[j])
                    #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                    #print("year", metric[0], metric[2])
                    influx_metric = [{
                        'measurement': 'socialweather', #name of the table 
                        'tags': {
                            'normalized': "no"
                        },
                        'time': str(date)+"-12-31"+"T00:00:00Z",
                        'fields': {
                            narr[i] : float(metric[j]) #value of field
                        }
                    }]
                    print(influx_metric)
                    client.write_points(influx_metric)
                except:
                    print("no")  
            date=date+1;
main()
# Out:
# Create DataFrame
# [[['' 'iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']]]
# ['iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']
# ['iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']
# ['iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus']
# ['iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus']
# Create database: socialweather_norm
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'Number of Attacks': 468.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'Number of Attacks': 247.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'Number of Attacks': 64.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'Number of Attacks': 58.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'Number of Attacks': 94.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'Number of Attacks': 149.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'Number of Attacks': 105.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'Number of Attacks': 130.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'Number of Attacks': 87.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'Number of Attacks': 69.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'Number of Attacks': 67.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'Number of Attacks': 73.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'Number of Attacks': 78.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'Number of Attacks': 44.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'Number of Attacks': 63.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'Number of Attacks': 40.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'Number of Attacks': 49.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'Number of Attacks': 34.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'Number of Attacks': 27.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'Number of Attacks': 42.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'Number of Attacks': 32.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'Number of Attacks': 30.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'Number of Attacks': 32.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'Number of Attacks': 56.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'Number of Attacks': 60.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'Number of Attacks': 35.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'Number of Attacks': 40.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'Number of Attacks': 30.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'Number of Attacks': 53.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'Number of Attacks': 32.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'Number of Attacks': 41.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'Number of Attacks': 33.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'Number of Attacks': 32.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'Number of Attacks': 9.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'Number of Attacks': 20.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'Number of Attacks': 6.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'Number of Attacks': 9.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'Number of Attacks': 18.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'Number of Attacks': 10.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'Number of Attacks': 17.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'Number of Attacks': 10.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'Number of Attacks': 19.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'Number of Attacks': 20.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'Number of Attacks': 26.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'Number of Attacks': 39.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'Number of Attacks': 61.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'nkill': 33.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'nkill': 20.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'nkill': 10.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'nkill': 45.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'nkill': 16.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'nkill': 24.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'nkill': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'nkill': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'nkill': 8.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'nkill': 18.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'nkill': 15.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'nkill': 8.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'nkill': 11.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'nkill': 8.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'nkill': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'nkill': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'nkill': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'nkill': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'nkill': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'nkill': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'nkill': 5.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'nkill': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'nkill': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'nkill': 10.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'nkill': 170.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'nkill': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'nkill': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'nkill': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'nkill': 20.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'nkill': 3005.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'nkill': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'nkill': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'nkill': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'nkill': 18.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'nkill': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'nkill': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'nkill': 7.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'nkill': 23.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'nkill': 19.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'nkill': 44.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'nkill': 68.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1970-12-31T00:00:00Z', 'fields': {'nkillus': 27.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1971-12-31T00:00:00Z', 'fields': {'nkillus': 15.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1972-12-31T00:00:00Z', 'fields': {'nkillus': 5.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1973-12-31T00:00:00Z', 'fields': {'nkillus': 37.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1974-12-31T00:00:00Z', 'fields': {'nkillus': 11.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1975-12-31T00:00:00Z', 'fields': {'nkillus': 7.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1976-12-31T00:00:00Z', 'fields': {'nkillus': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1977-12-31T00:00:00Z', 'fields': {'nkillus': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1978-12-31T00:00:00Z', 'fields': {'nkillus': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1979-12-31T00:00:00Z', 'fields': {'nkillus': 10.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1980-12-31T00:00:00Z', 'fields': {'nkillus': 11.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1981-12-31T00:00:00Z', 'fields': {'nkillus': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1982-12-31T00:00:00Z', 'fields': {'nkillus': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1983-12-31T00:00:00Z', 'fields': {'nkillus': 6.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1984-12-31T00:00:00Z', 'fields': {'nkillus': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1985-12-31T00:00:00Z', 'fields': {'nkillus': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1986-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1987-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1988-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1989-12-31T00:00:00Z', 'fields': {'nkillus': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1990-12-31T00:00:00Z', 'fields': {'nkillus': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1991-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1992-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1993-12-31T00:00:00Z', 'fields': {'nkillus': 6.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1994-12-31T00:00:00Z', 'fields': {'nkillus': 170.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1995-12-31T00:00:00Z', 'fields': {'nkillus': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1996-12-31T00:00:00Z', 'fields': {'nkillus': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1997-12-31T00:00:00Z', 'fields': {'nkillus': 3.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1998-12-31T00:00:00Z', 'fields': {'nkillus': 20.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '1999-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2000-12-31T00:00:00Z', 'fields': {'nkillus': 2908.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2001-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2002-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2003-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2004-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2005-12-31T00:00:00Z', 'fields': {'nkillus': 1.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2006-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2007-12-31T00:00:00Z', 'fields': {'nkillus': 2.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2008-12-31T00:00:00Z', 'fields': {'nkillus': 18.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2009-12-31T00:00:00Z', 'fields': {'nkillus': 4.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2010-12-31T00:00:00Z', 'fields': {'nkillus': 0.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2011-12-31T00:00:00Z', 'fields': {'nkillus': 6.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2012-12-31T00:00:00Z', 'fields': {'nkillus': 21.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2013-12-31T00:00:00Z', 'fields': {'nkillus': 19.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2014-12-31T00:00:00Z', 'fields': {'nkillus': 43.0}}]
# [{'measurement': 'socialweather', 'tags': {'normalized': 'no'}, 'time': '2015-12-31T00:00:00Z', 'fields': {'nkillus': 59.0}}]

# %%
def read_data():
    with open('terr_norm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[1:]]
def read_header():
    with open('terr_norm.csv') as f: #Input the name of your csv file here
        return [x.split(',') for x in f.readlines()[:1]]
def main(host='35.196.46.176', port=8086):       #input your port number which has been set for influx
    """Instantiate the connection to the InfluxDB client."""
    user = 'admin'
    password = 'admin'
    dbname = 'socialweather_norm'
    # Temporarily avoid line protocol time conversion issues #412, #426, #431.
    protocol = 'json'
    
    client = InfluxDBClient(host, port, user, password, dbname)

    print("Create DataFrame");
    b=read_header();
    arr = np.array([b]);
    print(arr)
    narr=np.delete(arr,0) # remove the date column
    print(narr)
    length=len(narr);
    print(narr); # getting /n (new line?,why?)
    narr[length-1]=narr[length-1].replace("\n",""); 
    print(narr); #removed /n
    a=read_data()
    print(narr); #removed /n
    print("Create database: " + dbname)
    client.create_database(dbname)
    j=0;
    influx_metric=[]
    for i in range(len(narr)):
        j=j+1;
        date=1970
        for metric in a:
            metric[j]=metric[j].replace("\n",""); # same as line 31
            narr[i]
            if(narr[i]!='iyear'):
                try:
                    float(metric[j])
                    #print(narr[i],metric[j],str(date)+"-12-31"+"T00:00:00Z")
                    #print("year", metric[0], metric[2])
                    influx_metric = [{
                        'measurement': 'socialweather', #name of the table 
                        'tags': {
                            'normalized': "yes"
                        },
                        'time': str(date)+"-12-31"+"T00:00:00Z",
                        'fields': {
                            narr[i] : float(metric[j]) #value of field
                        }
                    }]
                    print(influx_metric)
                    client.write_points(influx_metric)
                except:
                    print("no")  
            date=date+1;
main()
# Out:
# Create DataFrame
# [[['iyear' 'country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']]]
# ['country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']
# ['country_txt' 'Number of Attacks' 'nkill' 'nkillus\n']
# ['country_txt' 'Number of Attacks' 'nkill' 'nkillus']
# ['country_txt' 'Number of Attacks' 'nkill' 'nkillus']
# Create database: socialweather_norm
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# [{'measurement': 'socialweather', 'tags': {'normalized': 'yes'}, 'time': '1970-12-31T00:00:00Z', 'fields': {